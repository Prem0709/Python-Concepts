# %%
f1 = 3e0
f1
# Out:
# 3.0

# %%
i=23
i
# Out:
# 23

# %%
f3=2.3e4
f3
# Out:
# 23000.0

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
True+False
# Out:
# 1

# %%
True+True
# Out:
# 2

# %%
True+False+True-False
# Out:
# 2

# %%
True+(False+True)-True
# Out:
# 1

# %%
True+(False*True)-True
# Out:
# 0

# %%
print(True*2)
# Out:
# 2

# %%
num1=23
num2=43
add=num1+num2
print("the addition of ", num1 ,"and",num2,"is=",add)
# Out:
# the addition of  23 and 43 is= 66

# %%
complex

# %%
# complex = a +bj syntax of complex

# %%
# a -real part
# b is imaginary part
